# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the file paths
lines_file = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/Cornell_Movie_Dialogue_Corpus/movie_lines.txt"
conversation_file = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/Cornell_Movie_Dialogue_Corpus/movie_conversations.txt"

# Read the lines file with specified encoding
lines = pd.read_csv(lines_file, sep=r'\s*\+\+\+\$\+\+\+\s*', header=None, engine='python', encoding='ISO-8859-1')
lines.columns = ['line_id', 'character_id', 'movie_id', 'character', 'text']

# Read the conversations file with specified encoding
conversations = pd.read_csv(conversation_file, sep=r'\s*\+\+\+\$\+\+\+\s*', header=None, engine='python', encoding='ISO-8859-1')
conversations.columns = ['character1_id', 'character2_id', 'movie_id', 'utterance_ids']

# Display the first few rows of each DataFrame
print(lines.head())
print(conversations.head())
# Out:
#   line_id character_id movie_id character          text
# 0   L1045           u0       m0    BIANCA  They do not!
# 1   L1044           u2       m0   CAMERON   They do to!
# 2    L985           u0       m0    BIANCA    I hope so.
# 3    L984           u2       m0   CAMERON     She okay?
# 4    L925           u0       m0    BIANCA     Let's go.
#   character1_id character2_id movie_id                     utterance_ids
# 0            u0            u2       m0  ['L194', 'L195', 'L196', 'L197']
# 1            u0            u2       m0                  ['L198', 'L199']
# 2            u0            u2       m0  ['L200', 'L201', 'L202', 'L203']
# 3            u0            u2       m0          ['L204', 'L205', 'L206']
# 4            u0            u2       m0                  ['L207', 'L208']

# %%
from tqdm import tqdm

# Create a function to extract the conversation history and responses
def create_dataset(conversations, lines):
    # Create a dictionary for fast line access
    line_dict = dict(zip(lines['line_id'], lines['text']))

    dataset = []

    # Use tqdm to show progress
    for _, row in tqdm(conversations.iterrows(), total=conversations.shape[0], desc="Processing conversations"):
        utterance_ids = row['utterance_ids'].strip('[]').replace("'", "").split(', ')

        # Initialize conversation history
        conversation_history = []

        for utterance_id in utterance_ids:
            # Access the text from the dictionary
            text = line_dict.get(utterance_id)
            if isinstance(text, str):  # Ensure text is a string
                # Add the current line to the history
                conversation_history.append(text)

                # Create a record with the current history and response
                if len(conversation_history) > 1:
                    # The last entry is the response
                    response = conversation_history[-1]
                    history = conversation_history[:-1]

                    # Ensure that the history is made of strings
                    dataset.append({
                        'conversation_history': ' '.join(h for h in history if isinstance(h, str)),
                        'response': response
                    })

    return pd.DataFrame(dataset)

# Create the dataset
import time

start_time = time.time()
chatbot_dataset = create_dataset(conversations, lines)
end_time = time.time()

# Display the first few rows of the dataset
print(f"Execution Time: {end_time - start_time} seconds")
# Out:
# Processing conversations: 100%|██████████| 83097/83097 [00:04<00:00, 18233.39it/s]
# Execution Time: 4.896346092224121 seconds

# %%
chatbot_dataset.head()
# Out:
#                                 conversation_history  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  Can we make this quick?  Roxanne Korrine and A...
# 2  Can we make this quick?  Roxanne Korrine and A...
# 3  You're asking me out.  That's so cute. What's ...
# 4  No, no, it's my fault -- we didn't have a prop...
#
#                                             response
# 0  Well, I thought we'd start with pronunciation,...
# 1  Not the hacking and gagging and spitting part....
# 2  Okay... then how 'bout we try out some French ...
# 3                                         Forget it.
# 4                                           Cameron.

# %%
chatbot_dataset.to_csv("/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/attempt_2.csv", index=False)

# %% [markdown]
# ## Model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW
from tqdm import tqdm

# %%
# Load your dataset (adjust the path as necessary)
# chatbot_dataset = pd.read_csv('path/to/your/cornell_movie_chatbot_dataset.csv')

# %%
# Split the dataset into train and test sets (80% train, 20% test)
train_data, test_data = train_test_split(chatbot_dataset, test_size=0.2, random_state=42)

# Further split the train data into training and validation sets (80% train, 20% validation)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

# Display the sizes of the datasets
print(f"Training set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Training set size: 141674
# Validation set size: 35419
# Test set size: 44274

# %%
# Load the GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# Set pad token to be the same as the end-of-sequence token
tokenizer.pad_token = tokenizer.eos_token

# Tokenize the datasets
def tokenize_data(data):
    return tokenizer(
        data['conversation_history'].tolist(),
        truncation=True,
        padding='max_length',
        max_length=100,
        return_tensors='pt'
        )

# Tokenize each split
train_encodings = tokenize_data(train_data)
val_encodings = tokenize_data(val_data)
test_encodings = tokenize_data(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
class ChatbotDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings['input_ids'])

# Create datasets for training, validation, and testing
train_dataset = ChatbotDataset(train_encodings)
val_dataset = ChatbotDataset(val_encodings)
test_dataset = ChatbotDataset(test_encodings)

# %%
# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, num_workers=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, num_workers=4, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, num_workers=4, shuffle=False)

# %%
# Load the pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
# Step 9: Check for GPU Availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Move the model to the GPU
model.to(device)

# Step 10: Define Optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# Step 11: Training Loop with Validation
for epoch in range(3):  # Number of epochs
    start_time = time.time()  # Start time for the epoch
    model.train()  # Set model to training mode

    # Training phase
    for batch in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}"):
        optimizer.zero_grad()

        # Move input data to the GPU
        input_ids = batch['input_ids'].to(device)

        outputs = model(input_ids=input_ids, labels=input_ids)
        loss = outputs.loss
        loss.backward()
        optimizer.step()

    # Validation step
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Validating"):
            # Move input data to the GPU
            input_ids = batch['input_ids'].to(device)
            outputs = model(input_ids=input_ids, labels=input_ids)
            val_loss += outputs.loss.item()

    # Calculate the time taken for the epoch
    end_time = time.time()
    epoch_time = end_time - start_time

    # Print training and validation losses along with epoch time
    print(f"Epoch: {epoch + 1}, Training Loss: {loss.item():.4f}, Validation Loss: {val_loss / len(val_loader):.4f}, Time: {epoch_time:.2f} seconds")
# Out:
# Using device: cuda
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Training Epoch 1: 100%|██████████| 8855/8855 [30:56<00:00,  4.77it/s]
# Validating: 100%|██████████| 2214/2214 [02:20<00:00, 15.78it/s]
# Epoch: 1, Training Loss: 1.7537, Validation Loss: 1.1485, Time: 1996.72 seconds
# Training Epoch 2: 100%|██████████| 8855/8855 [30:56<00:00,  4.77it/s]
# Validating: 100%|██████████| 2214/2214 [02:20<00:00, 15.76it/s]
# Epoch: 2, Training Loss: 1.1251, Validation Loss: 0.9990, Time: 1996.63 seconds
# Training Epoch 3: 100%|██████████| 8855/8855 [30:56<00:00,  4.77it/s]
# Validating: 100%|██████████| 2214/2214 [02:20<00:00, 15.75it/s]
# Epoch: 3, Training Loss: 0.9020, Validation Loss: 0.8982, Time: 1997.07 seconds

# %%
# Saving the model
gpt_model = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_model"
gpt_tokenizer = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_tokenizer"

# Save the model and tokenizer
model.save_pretrained(gpt_model)
tokenizer.save_pretrained(gpt_tokenizer)
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_tokenizer/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_tokenizer/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_tokenizer/vocab.json',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_tokenizer/merges.txt',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_tokenizer/added_tokens.json')

# %%
pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.5)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=3a3dd6912fbe83279b5ab3c24548933089068a3e2fb36ed515a655a855f74568
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
import numpy as np
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score

# %%
# Sample function to compute the average loss and perplexity
def compute_average_loss_and_perplexity(loader, model, device):
    model.eval()
    total_loss = 0
    num_batches = 0

    # Start timing
    start_time = time.time()

    with torch.no_grad():
        # Use tqdm to show progress
        for batch in tqdm(loader, desc="Computing Average Loss and Perplexity"):
            input_ids = batch['input_ids'].to(device)
            outputs = model(input_ids=input_ids, labels=input_ids)
            loss = outputs.loss
            total_loss += loss.item()
            num_batches += 1

    avg_loss = total_loss / num_batches
    perplexity = np.exp(avg_loss)

    # Calculate the time taken
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time taken: {elapsed_time:.2f} seconds")

    return avg_loss, perplexity

# Assuming you have a validation DataLoader
avg_loss, perplexity = compute_average_loss_and_perplexity(val_loader, model, device)
print(f"Average Loss: {avg_loss:.4f}, Perplexity: {perplexity:.4f}")
# Out:
# Computing Average Loss and Perplexity: 100%|██████████| 2214/2214 [02:20<00:00, 15.75it/s]
# Time taken: 140.54 seconds
# Average Loss: 0.8982, Perplexity: 2.4551

# %%
import numpy as np
import torch
from tqdm import tqdm
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Load the GPT-2 tokenizer with left padding
tokenizer = GPT2Tokenizer.from_pretrained('gpt2', padding_side='left')
tokenizer.pad_token = tokenizer.eos_token  # Assign pad token
tokenizer.pad_token_id = tokenizer.eos_token_id  # Ensure padding ID is the same as EOS

# Load the pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Step 3: Generate Predictions for the Test Dataset
model.eval()
predictions = []
references = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Generating Predictions"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)  # Ensure the attention mask is used

        # Generate outputs
        outputs = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=50,
            num_return_sequences=1
        )

        # Decode the generated output
        generated_texts = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
        predictions.extend(generated_texts)

        # Collect reference texts (assuming input_ids corresponds to the expected outputs)
        reference_texts = [tokenizer.decode(ids, skip_special_tokens=True) for ids in input_ids]
        references.extend(reference_texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# Generating Predictions:  10%|▉         | 269/2768 [02:38<24:27,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 270/2768 [02:39<24:26,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 271/2768 [02:39<24:26,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 272/2768 [02:40<24:31,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 273/2768 [02:40<24:29,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 274/2768 [02:41<24:29,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 275/2768 [02:42<24:22,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|▉         | 276/2768 [02:42<24:23,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 277/2768 [02:43<24:20,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 278/2768 [02:43<24:18,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 279/2768 [02:44<24:39,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 280/2768 [02:45<24:26,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 281/2768 [02:45<24:39,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 282/2768 [02:46<24:27,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 283/2768 [02:46<24:57,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 284/2768 [02:47<24:52,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 285/2768 [02:48<24:34,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 286/2768 [02:48<24:24,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 287/2768 [02:49<24:16,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 288/2768 [02:49<24:15,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 289/2768 [02:50<24:45,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  10%|█         | 290/2768 [02:50<24:32,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 291/2768 [02:51<24:28,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 292/2768 [02:52<24:22,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 293/2768 [02:52<24:21,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 294/2768 [02:53<24:34,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 295/2768 [02:53<24:30,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 296/2768 [02:54<24:23,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 297/2768 [02:55<24:19,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 298/2768 [02:55<24:17,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 299/2768 [02:56<24:23,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 300/2768 [02:56<24:18,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 301/2768 [02:57<24:22,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 302/2768 [02:58<24:18,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 303/2768 [02:58<24:11,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 304/2768 [02:59<24:14,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 305/2768 [02:59<24:11,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 306/2768 [03:00<24:05,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 307/2768 [03:01<23:59,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 308/2768 [03:01<23:56,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 309/2768 [03:02<23:55,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 310/2768 [03:02<23:59,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█         | 311/2768 [03:03<23:50,  1.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 312/2768 [03:03<23:50,  1.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 313/2768 [03:04<24:10,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 314/2768 [03:05<24:00,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 315/2768 [03:05<23:56,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 316/2768 [03:06<23:56,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 317/2768 [03:06<23:59,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  11%|█▏        | 318/2768 [03:07<24:14,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 319/2768 [03:08<24:04,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 320/2768 [03:08<23:54,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 321/2768 [03:09<23:59,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 322/2768 [03:09<23:58,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 323/2768 [03:10<23:50,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 324/2768 [03:10<23:45,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 325/2768 [03:11<23:44,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 326/2768 [03:12<23:43,  1.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 327/2768 [03:12<23:41,  1.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 328/2768 [03:13<23:36,  1.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 329/2768 [03:13<23:36,  1.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 330/2768 [03:14<23:46,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 331/2768 [03:15<23:47,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 332/2768 [03:15<23:48,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 333/2768 [03:16<23:45,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 334/2768 [03:16<23:57,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 335/2768 [03:17<24:03,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 336/2768 [03:18<24:01,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 337/2768 [03:18<23:50,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 338/2768 [03:19<23:47,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 339/2768 [03:19<23:39,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 340/2768 [03:20<23:55,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 341/2768 [03:20<23:52,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 342/2768 [03:21<24:05,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 343/2768 [03:22<23:59,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 344/2768 [03:22<23:55,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▏        | 345/2768 [03:23<23:46,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  12%|█▎        | 346/2768 [03:23<23:52,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 347/2768 [03:24<23:47,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 348/2768 [03:25<23:44,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 349/2768 [03:25<23:49,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 350/2768 [03:26<23:37,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 351/2768 [03:26<23:35,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 352/2768 [03:27<23:31,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 353/2768 [03:28<23:45,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 354/2768 [03:28<23:58,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 355/2768 [03:29<23:44,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 356/2768 [03:29<23:39,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 357/2768 [03:30<23:41,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 358/2768 [03:30<23:40,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 359/2768 [03:31<23:37,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 360/2768 [03:32<23:42,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 361/2768 [03:32<23:35,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 362/2768 [03:33<23:52,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 363/2768 [03:33<23:40,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 364/2768 [03:34<23:35,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 365/2768 [03:35<23:36,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 366/2768 [03:35<23:42,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 367/2768 [03:36<23:52,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 368/2768 [03:36<23:45,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 369/2768 [03:37<23:37,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 370/2768 [03:38<23:35,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 371/2768 [03:38<23:47,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 372/2768 [03:39<23:43,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  13%|█▎        | 373/2768 [03:39<23:37,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 374/2768 [03:40<23:38,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 375/2768 [03:41<23:42,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 376/2768 [03:41<23:46,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 377/2768 [03:42<23:37,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 378/2768 [03:42<23:30,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 379/2768 [03:43<23:33,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▎        | 380/2768 [03:44<23:43,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 381/2768 [03:44<23:47,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 382/2768 [03:45<24:16,  1.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 383/2768 [03:45<23:57,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 384/2768 [03:46<23:58,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 385/2768 [03:47<23:47,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 386/2768 [03:47<23:41,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 387/2768 [03:48<24:06,  1.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 388/2768 [03:48<23:53,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 389/2768 [03:49<23:48,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 390/2768 [03:50<23:37,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 391/2768 [03:50<23:25,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 392/2768 [03:51<23:26,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 393/2768 [03:51<23:19,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 394/2768 [03:52<23:22,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 395/2768 [03:52<23:16,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 396/2768 [03:53<23:13,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 397/2768 [03:54<23:17,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 398/2768 [03:54<23:13,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 399/2768 [03:55<23:09,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 400/2768 [03:55<23:10,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  14%|█▍        | 401/2768 [03:56<23:22,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 402/2768 [03:57<23:25,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 403/2768 [03:57<23:18,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 404/2768 [03:58<23:21,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 405/2768 [03:58<23:30,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 406/2768 [03:59<23:24,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 407/2768 [04:00<23:19,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 408/2768 [04:00<23:11,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 409/2768 [04:01<23:10,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 410/2768 [04:01<23:05,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 411/2768 [04:02<23:05,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 412/2768 [04:03<23:05,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 413/2768 [04:03<23:12,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 414/2768 [04:04<23:06,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▍        | 415/2768 [04:04<23:07,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▌        | 416/2768 [04:05<23:04,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▌        | 417/2768 [04:05<22:54,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  15%|█▌        | 418/2768 [04:06<22:55,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2719/2768 [26:51<00:29,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2720/2768 [26:51<00:28,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2721/2768 [26:52<00:28,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2722/2768 [26:53<00:27,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2723/2768 [26:53<00:26,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2724/2768 [26:54<00:26,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2725/2768 [26:54<00:25,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  98%|█████████▊| 2726/2768 [26:55<00:25,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2727/2768 [26:56<00:24,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2728/2768 [26:56<00:23,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2729/2768 [26:57<00:23,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2730/2768 [26:57<00:23,  1.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2731/2768 [26:58<00:22,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2732/2768 [26:59<00:21,  1.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▊| 2733/2768 [26:59<00:21,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2734/2768 [27:00<00:20,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2735/2768 [27:00<00:19,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2736/2768 [27:01<00:19,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2737/2768 [27:02<00:18,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2738/2768 [27:02<00:17,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2739/2768 [27:03<00:17,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2740/2768 [27:03<00:16,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2741/2768 [27:04<00:16,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2742/2768 [27:05<00:15,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2743/2768 [27:05<00:14,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2744/2768 [27:06<00:14,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2745/2768 [27:06<00:13,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2746/2768 [27:07<00:13,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2747/2768 [27:07<00:12,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2748/2768 [27:08<00:11,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2749/2768 [27:09<00:11,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2750/2768 [27:09<00:10,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2751/2768 [27:10<00:10,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2752/2768 [27:10<00:09,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2753/2768 [27:11<00:08,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions:  99%|█████████▉| 2754/2768 [27:12<00:08,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2755/2768 [27:12<00:07,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2756/2768 [27:13<00:07,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2757/2768 [27:13<00:06,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2758/2768 [27:14<00:05,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2759/2768 [27:15<00:05,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2760/2768 [27:15<00:04,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2761/2768 [27:16<00:04,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2762/2768 [27:16<00:03,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2763/2768 [27:17<00:03,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2764/2768 [27:18<00:02,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2765/2768 [27:18<00:01,  1.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2766/2768 [27:19<00:01,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|█████████▉| 2767/2768 [27:19<00:00,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating Predictions: 100%|██████████| 2768/2768 [27:20<00:00,  1.69it/s]

# %%
# Function to compute BLEU, ROUGE, and METEOR scores
def compute_nlp_metrics(predictions, references):
    # Start timing
    start_time = time.time()

    # BLEU score
    bleu_scores = []
    for pred, ref in tqdm(zip(predictions, references), desc="Calculating BLEU"):
        bleu_scores.append(sentence_bleu([ref.split()], pred.split()))
    avg_bleu = np.mean(bleu_scores)

    # ROUGE score
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = []
    for pred, ref in tqdm(zip(predictions, references), desc="Calculating ROUGE"):
        rouge_scores.append(scorer.score(ref, pred))
    avg_rouge = {
        'rouge1': np.mean([score['rouge1'].fmeasure for score in rouge_scores]),
        'rouge2': np.mean([score['rouge2'].fmeasure for score in rouge_scores]),
        'rougeL': np.mean([score['rougeL'].fmeasure for score in rouge_scores]),
    }

    # METEOR score
    meteor_scores = []
    for pred, ref in tqdm(zip(predictions, references), desc="Calculating METEOR"):
        meteor_scores.append(meteor_score(ref.split(), pred.split()))
    avg_meteor = np.mean(meteor_scores)

    # Calculate total time taken
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time taken for metric calculations: {elapsed_time:.2f} seconds")

    return avg_bleu, avg_rouge, avg_meteor

# Compute BLEU, ROUGE, and METEOR scores using the test dataset
avg_bleu, avg_rouge, avg_meteor = compute_nlp_metrics(predictions, references)

# Print the results
print(f"Average BLEU: {avg_bleu:.4f}, Average ROUGE: {avg_rouge}, Average METEOR: {avg_meteor:.4f}")
# Out:
# Calculating BLEU: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Calculating BLEU: 44274it [00:10, 4044.22it/s]
# Calculating ROUGE: 44274it [01:32, 479.85it/s]
# Calculating METEOR: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-5867718b0b34> in <cell line: 37>()
#      35
#      36 # Compute BLEU, ROUGE, and METEOR scores using the test dataset
# ---> 37 avg_bleu, avg_rouge, avg_meteor = compute_nlp_metrics(predictions, references)
#      38
#      39 # Print the results
#
# <ipython-input-36-5867718b0b34> in compute_nlp_metrics(predictions, references)
#      24     meteor_scores = []
#      25     for pred, ref in tqdm(zip(predictions, references), desc="Calculating METEOR"):
# ---> 26         meteor_scores.append(meteor_score(ref.split(), pred.split()))
#      27     avg_meteor = np.mean(meteor_scores)
#      28
#
# /usr/local/lib/python3.10/dist-packages/nltk/translate/meteor_score.py in meteor_score(references, hypothesis, preprocess, stemmer, wordnet, alpha, beta, gamma)
#     395     :return: The sentence-level METEOR score.
#     396     """
# --> 397     return max(
#     398         single_meteor_score(
#     399             reference,
#
# /usr/local/lib/python3.10/dist-packages/nltk/translate/meteor_score.py in <genexpr>(.0)
#     396     """
#     397     return max(
# --> 398         single_meteor_score(
#     399             reference,
#     400             hypothesis,
#
# /usr/local/lib/python3.10/dist-packages/nltk/translate/meteor_score.py in single_meteor_score(reference, hypothesis, preprocess, stemmer, wordnet, alpha, beta, gamma)
#     324     :return: The sentence-level METEOR score.
#     325     """
# --> 326     enum_hypothesis, enum_reference = _generate_enums(
#     327         hypothesis, reference, preprocess=preprocess
#     328     )
#
# /usr/local/lib/python3.10/dist-packages/nltk/translate/meteor_score.py in _generate_enums(hypothesis, reference, preprocess)
#      36
#      37     if isinstance(reference, str):
# ---> 38         raise TypeError(
#      39             f'"reference" expects pre-tokenized reference (Iterable[str]): {reference}'
#      40         )
#
# TypeError: "reference" expects pre-tokenized reference (Iterable[str]): Are

# %%
# Load the GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Set the pad token to the end-of-sequence token
tokenizer.pad_token = tokenizer.eos_token  # Assign pad token
tokenizer.pad_token_id = tokenizer.eos_token_id  # Ensure padding ID is the same as EOS

# Set the model to evaluation mode
model.eval()

print("Chatbot is ready! Type 'exit' to stop the conversation.")

while True:
    # Get user input
    input_text = input("You: ")

    # Check for exit condition
    if input_text.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye!")
        break

    # Tokenize the input
    encoded_input = tokenizer.encode_plus(
        input_text,
        return_tensors='pt',
        padding='max_length',
        truncation=True,
        max_length=50,
        clean_up_tokenization_spaces=True  # Set to avoid warnings
    )

    input_ids = encoded_input['input_ids'].to(device)
    attention_mask = encoded_input['attention_mask'].to(device)

    # Generate output
    with torch.no_grad():
        output = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=50,  # Generate up to 50 new tokens
            num_return_sequences=1
        )

    # Decode the generated output
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    print(f"Chatbot: {response}")
# Out:
# Chatbot is ready! Type 'exit' to stop the conversation.
# You: Hello
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Hello, I'm calling from... If you're selling something, I'm late for work... I'm calling from Professional Nurse Quarterly... From the magazine? This is Mr. Wallace in Subscriptions? How come you're calling me from...? This is
# You: what are you talking about
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: what are you talking about
# You: who are you calling?
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: who are you calling?
# You: you are copying me
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: you are copying me
# You: stop
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: stop, I'm sorry.  I was just... I was just... I was just... I was just... I was just... I was just so excited.  I was so excited.  I was so excited to get out of here.
# You: you are getting out of the computer?
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: you are getting out of the computer?
# You: what?
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: what?
# You: help me
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: help me
# You: please
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: please, I'm sorry.  I was just... I was just... I was just... I was just... I was just so excited.  I was so excited to get out of here.  I was so excited to get back.  And
# You: no
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: no, I'm not.  I'm not.  I'm not.  I'm not.  I'm not.  I'm not.  I'm not.  I'm not.  I'm not.  I'm not.
# You: exit
# Chatbot: Goodbye!
