# %%
import pandas as pd
import time
from tqdm import tqdm
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the file paths
lines_file = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/Cornell_Movie_Dialogue_Corpus/movie_lines.txt"
conversation_file = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/Cornell_Movie_Dialogue_Corpus/movie_conversations.txt"

# Read the lines file with specified encoding
lines = pd.read_csv(lines_file, sep=r'\s*\+\+\+\$\+\+\+\s*', header=None, engine='python', encoding='ISO-8859-1')
lines.columns = ['line_id', 'character_id', 'movie_id', 'character', 'text']

# Read the conversations file with specified encoding
conversations = pd.read_csv(conversation_file, sep=r'\s*\+\+\+\$\+\+\+\s*', header=None, engine='python', encoding='ISO-8859-1')
conversations.columns = ['character1_id', 'character2_id', 'movie_id', 'utterance_ids']

# Display the first few rows of each DataFrame
print(lines.head())
print(conversations.head())
# Out:
#   line_id character_id movie_id character          text
# 0   L1045           u0       m0    BIANCA  They do not!
# 1   L1044           u2       m0   CAMERON   They do to!
# 2    L985           u0       m0    BIANCA    I hope so.
# 3    L984           u2       m0   CAMERON     She okay?
# 4    L925           u0       m0    BIANCA     Let's go.
#   character1_id character2_id movie_id                     utterance_ids
# 0            u0            u2       m0  ['L194', 'L195', 'L196', 'L197']
# 1            u0            u2       m0                  ['L198', 'L199']
# 2            u0            u2       m0  ['L200', 'L201', 'L202', 'L203']
# 3            u0            u2       m0          ['L204', 'L205', 'L206']
# 4            u0            u2       m0                  ['L207', 'L208']

# %%
# Function to clean the text
def clean_text(text):
    # Retain specific punctuation and remove others
    text = re.sub(r"[^\w\s.!?'’]", '', text)  # Keep punctuation and apostrophes
    text = text.strip()  # Strip whitespace
    text = ' '.join(text.split())  # Normalize whitespace
    return text

# %%
# Create a function to extract the conversation history and responses
def create_dataset(conversations, lines):
    # Create a dictionary for fast line access
    line_dict = dict(zip(lines['line_id'], lines['text']))

    dataset = []

    # Use tqdm to show progress
    for _, row in tqdm(conversations.iterrows(), total=conversations.shape[0], desc="Processing conversations"):
        utterance_ids = row['utterance_ids'].strip('[]').replace("'", "").split(', ')

        # Initialize conversation history
        conversation_history = []

        for utterance_id in utterance_ids:
            # Access the text from the dictionary
            text = line_dict.get(utterance_id)
            if isinstance(text, str):  # Ensure text is a string
                # Add the current line to the history
                conversation_history.append(text)

                # Create a record with the current history and response
                if len(conversation_history) > 1:
                    # The last entry is the response
                    response = conversation_history[-1]
                    history = conversation_history[:-1]

                    # Ensure that the history is made of strings
                    dataset.append({
                        'conversation_history': ' '.join(h for h in history if isinstance(h, str)),
                        'response': response
                    })

    return pd.DataFrame(dataset)

# %%
# Create the dataset
start_time = time.time()
chatbot_dataset = create_dataset(conversations, lines)
end_time = time.time()

# Clean the conversation history and responses, replacing the original columns
chatbot_dataset['conversation_history'] = chatbot_dataset['conversation_history'].apply(clean_text)
chatbot_dataset['response'] = chatbot_dataset['response'].apply(clean_text)

# Display the first few rows of the cleaned dataset
print(chatbot_dataset[['conversation_history', 'response']].head())
print(f"Execution Time: {end_time - start_time} seconds")
# Out:
# Processing conversations: 100%|██████████| 83097/83097 [00:04<00:00, 18372.11it/s]
#                                 conversation_history  \
# 0  Can we make this quick? Roxanne Korrine and An...
# 1  Can we make this quick? Roxanne Korrine and An...
# 2  Can we make this quick? Roxanne Korrine and An...
# 3  You're asking me out. That's so cute. What's y...
# 4  No no it's my fault we didn't have a proper in...
#
#                                             response
# 0  Well I thought we'd start with pronunciation i...
# 1  Not the hacking and gagging and spitting part....
# 2  Okay... then how 'bout we try out some French ...
# 3                                         Forget it.
# 4                                           Cameron.
# Execution Time: 4.8355553150177 seconds

# %%
chatbot_dataset.head()
# Out:
#                                 conversation_history  \
# 0  Can we make this quick? Roxanne Korrine and An...
# 1  Can we make this quick? Roxanne Korrine and An...
# 2  Can we make this quick? Roxanne Korrine and An...
# 3  You're asking me out. That's so cute. What's y...
# 4  No no it's my fault we didn't have a proper in...
#
#                                             response
# 0  Well I thought we'd start with pronunciation i...
# 1  Not the hacking and gagging and spitting part....
# 2  Okay... then how 'bout we try out some French ...
# 3                                         Forget it.
# 4                                           Cameron.

# %%
chatbot_dataset.to_csv("/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/attempt_2.csv", index=False)

# %% [markdown]
# ## Model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from torch.optim import AdamW
from tqdm import tqdm
import os

# %%
# Load your dataset (adjust the path as necessary)
# chatbot_dataset = pd.read_csv('path/to/your/cornell_movie_chatbot_dataset.csv')

# %%
# Split the dataset into train and test sets (80% train, 20% test)
train_data, test_data = train_test_split(chatbot_dataset, test_size=0.2, random_state=42)

# Further split the train data into training and validation sets (80% train, 20% validation)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

# Display the sizes of the datasets
print(f"Training set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Training set size: 141674
# Validation set size: 35419
# Test set size: 44274

# %%
# Load the GPT-2 tokenizer with left padding
tokenizer = GPT2Tokenizer.from_pretrained('gpt2', padding_side='left')
# Set pad token to be the same as the end-of-sequence token
tokenizer.pad_token = tokenizer.eos_token

# Tokenize the datasets with time tracking
def tokenize_data(data):
    start_time = time.time()  # Start the timer
    # Use tqdm to show progress while processing the dataset
    encodings = tokenizer(
        list(tqdm(data['conversation_history'].tolist(), desc="Tokenizing")),  # Wrap the list with tqdm
        truncation=True,
        padding='max_length',  # Ensure all sequences are the same length
        max_length=100,  # Set maximum length for the sequences
        return_tensors='pt',  # Return PyTorch tensors
        return_attention_mask=True,  # Include the attention mask
        add_special_tokens=True,  # Add special tokens if necessary
    )
    end_time = time.time()  # End the timer
    print(f"Time taken for tokenization: {end_time - start_time:.2f} seconds")  # Print the elapsed time
    return encodings

# Tokenize each split
train_encodings = tokenize_data(train_data)
val_encodings = tokenize_data(val_data)
test_encodings = tokenize_data(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Tokenizing: 100%|██████████| 141674/141674 [00:00<00:00, 2821964.21it/s]
# Time taken for tokenization: 42.36 seconds
# Tokenizing: 100%|██████████| 35419/35419 [00:00<00:00, 2567010.88it/s]
# Time taken for tokenization: 10.03 seconds
# Tokenizing: 100%|██████████| 44274/44274 [00:00<00:00, 2672730.11it/s]
# Time taken for tokenization: 12.28 seconds

# %%
class ChatbotDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings['input_ids'])

# Create datasets for training, validation, and testing
train_dataset = ChatbotDataset(train_encodings)
val_dataset = ChatbotDataset(val_encodings)
test_dataset = ChatbotDataset(test_encodings)

# %%
# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, num_workers=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, num_workers=4, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, num_workers=4, shuffle=False)

# %%
# Load the pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Step 9: Check for GPU Availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the checkpoint directory in Google Drive
checkpoint_dir = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint"
os.makedirs(checkpoint_dir, exist_ok=True)

# Move the model to the GPU
model.to(device)

# Step 10: Define Optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# Training Loop with Validation and Early Stopping
best_val_loss = float('inf')
patience = 3  # Number of epochs to wait for improvement
epochs_without_improvement = 0

# Step 11: Training Loop with Validation
for epoch in range(50):  # Number of epochs
    start_time = time.time()  # Start time for the epoch
    model.train()  # Set model to training mode

    # Training phase
    for batch in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}"):
        optimizer.zero_grad()

        # Move input data to the GPU
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)


                # Compute the loss
        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=input_ids)
        loss = outputs.loss
        loss.backward()
        optimizer.step()

    # Validation step
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Validating"):
            # Move input data to the GPU
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)  # Move attention mask to the device

            # Compute the loss
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=input_ids)
            val_loss += outputs.loss.item()

    # Calculate the time taken for the epoch
    end_time = time.time()
    epoch_time = end_time - start_time

    # Print training and validation losses along with epoch time
    print(f"Epoch: {epoch + 1}, Training Loss: {loss.item():.4f}, Validation Loss: {val_loss / len(val_loader):.4f}, Time: {epoch_time:.2f} seconds")

    # Check for improvement
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_without_improvement = 0  # Reset the counter
        checkpoint_path = os.path.join(checkpoint_dir, f"model_epoch_{epoch + 1}.pt")
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }, checkpoint_path)
        print(f"Checkpoint saved at {checkpoint_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs.")
            break
# Out:
# Using device: cuda
# Training Epoch 1: 100%|██████████| 4428/4428 [31:41<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:30<00:00,  7.33it/s]
# Epoch: 1, Training Loss: 1.1776, Validation Loss: 1.1920, Time: 2052.94 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_1.pt
# Training Epoch 2: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 2, Training Loss: 1.3148, Validation Loss: 1.0511, Time: 2053.52 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_2.pt
# Training Epoch 3: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 3, Training Loss: 1.0799, Validation Loss: 0.9433, Time: 2054.26 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_3.pt
# Training Epoch 4: 100%|██████████| 4428/4428 [31:43<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:30<00:00,  7.33it/s]
# Epoch: 4, Training Loss: 0.5881, Validation Loss: 0.8634, Time: 2054.01 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_4.pt
# Training Epoch 5: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:30<00:00,  7.33it/s]
# Epoch: 5, Training Loss: 0.9873, Validation Loss: 0.7996, Time: 2053.75 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_5.pt
# Training Epoch 6: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.33it/s]
# Epoch: 6, Training Loss: 0.5071, Validation Loss: 0.7484, Time: 2054.00 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_6.pt
# Training Epoch 7: 100%|██████████| 4428/4428 [31:43<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:30<00:00,  7.33it/s]
# Epoch: 7, Training Loss: 0.8941, Validation Loss: 0.7069, Time: 2054.04 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_7.pt
# Training Epoch 8: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.33it/s]
# Epoch: 8, Training Loss: 0.6186, Validation Loss: 0.6714, Time: 2054.04 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_8.pt
# Training Epoch 9: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:30<00:00,  7.33it/s]
# Epoch: 9, Training Loss: 0.7212, Validation Loss: 0.6417, Time: 2053.68 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_9.pt
# Training Epoch 10: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:30<00:00,  7.33it/s]
# Epoch: 10, Training Loss: 0.2442, Validation Loss: 0.6153, Time: 2053.66 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_10.pt
# Training Epoch 11: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.33it/s]
# Epoch: 11, Training Loss: 0.3690, Validation Loss: 0.5932, Time: 2053.99 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_11.pt
# Training Epoch 12: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.33it/s]
# Epoch: 12, Training Loss: 0.5515, Validation Loss: 0.5799, Time: 2053.88 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_12.pt
# Training Epoch 13: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 13, Training Loss: 0.3935, Validation Loss: 0.5619, Time: 2053.79 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_13.pt
# Training Epoch 14: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 14, Training Loss: 0.3121, Validation Loss: 0.5436, Time: 2053.97 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_14.pt
# Training Epoch 15: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.33it/s]
# Epoch: 15, Training Loss: 0.3989, Validation Loss: 0.5304, Time: 2053.77 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_15.pt
# Training Epoch 16: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 16, Training Loss: 0.5311, Validation Loss: 0.5237, Time: 2054.18 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_16.pt
# Training Epoch 17: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 17, Training Loss: 0.3987, Validation Loss: 0.5107, Time: 2054.10 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_17.pt
# Training Epoch 18: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 18, Training Loss: 0.7259, Validation Loss: 0.5042, Time: 2053.88 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_18.pt
# Training Epoch 19: 100%|██████████| 4428/4428 [31:43<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 19, Training Loss: 0.2596, Validation Loss: 0.4955, Time: 2054.29 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_19.pt
# Training Epoch 20: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 20, Training Loss: 0.1848, Validation Loss: 0.5003, Time: 2053.86 seconds
# Training Epoch 21: 100%|██████████| 4428/4428 [31:43<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.31it/s]
# Epoch: 21, Training Loss: 0.2736, Validation Loss: 0.4862, Time: 2054.49 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_21.pt
# Training Epoch 22: 100%|██████████| 4428/4428 [31:43<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 22, Training Loss: 0.1344, Validation Loss: 0.4834, Time: 2054.29 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_22.pt
# Training Epoch 23: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 23, Training Loss: 0.2159, Validation Loss: 0.4891, Time: 2054.02 seconds
# Training Epoch 24: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.33it/s]
# Epoch: 24, Training Loss: 0.1509, Validation Loss: 0.4830, Time: 2053.96 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_24.pt
# Training Epoch 25: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 25, Training Loss: 0.3293, Validation Loss: 0.4725, Time: 2053.91 seconds
# Checkpoint saved at /content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt_checkpoint/model_epoch_25.pt
# Training Epoch 26: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 26, Training Loss: 0.3247, Validation Loss: 0.4772, Time: 2054.05 seconds
# Training Epoch 27: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 27, Training Loss: 0.2051, Validation Loss: 0.4747, Time: 2054.15 seconds
# Training Epoch 28: 100%|██████████| 4428/4428 [31:42<00:00,  2.33it/s]
# Validating: 100%|██████████| 1107/1107 [02:31<00:00,  7.32it/s]
# Epoch: 28, Training Loss: 0.1361, Validation Loss: 0.4775, Time: 2054.10 seconds
# Early stopping triggered after 28 epochs.

# %%
# Saving the model
gpt_model = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch"
gpt_tokenizer = "/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch"

# Save the model and tokenizer
model.save_pretrained(gpt_model)
tokenizer.save_pretrained(gpt_tokenizer)
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch/vocab.json',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch/merges.txt',
#  '/content/drive/MyDrive/Colab Notebooks/AAI-520/Final Project/GenAI-Chatbot/eval/gpt/base_gpt_50_epoch/added_tokens.json')

# %%
pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.5)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=98750f13b13222ac6a8a8d921fc438aa860ec4dbe81d2800434261bcc91719b1
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
import numpy as np
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score

# %%
# Sample function to compute the average loss and perplexity
def compute_average_loss_and_perplexity(loader, model, device):
    model.eval()
    total_loss = 0
    num_batches = 0

    # Start timing
    start_time = time.time()

    with torch.no_grad():
        # Use tqdm to show progress
        for batch in tqdm(loader, desc="Computing Average Loss and Perplexity"):
            input_ids = batch['input_ids'].to(device)
            outputs = model(input_ids=input_ids, labels=input_ids)
            loss = outputs.loss
            total_loss += loss.item()
            num_batches += 1

    avg_loss = total_loss / num_batches
    perplexity = np.exp(avg_loss)

    # Calculate the time taken
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time taken: {elapsed_time:.2f} seconds")

    return avg_loss, perplexity

# Assuming you have a validation DataLoader
avg_loss, perplexity = compute_average_loss_and_perplexity(val_loader, model, device)
print(f"Average Loss: {avg_loss:.4f}, Perplexity: {perplexity:.4f}")
# Out:
# Computing Average Loss and Perplexity: 100%|██████████| 1107/1107 [02:29<00:00,  7.39it/s]
# Time taken: 149.73 seconds
# Average Loss: 1.1925, Perplexity: 3.2953

# %%
# Function to compute BLEU score
def compute_bleu(predictions, references):
    # Calculate BLEU score for each prediction
    bleu_scores = [sentence_bleu([ref.split()], pred.split()) for pred, ref in zip(predictions, references)]
    avg_bleu = np.mean(bleu_scores)  # Average BLEU score across all predictions
    return avg_bleu

# %%
import time
from tqdm import tqdm
import torch

# Start the timer
start_time = time.time()

# Generate predictions
model.eval()
predictions = []
references = []

# Use tqdm for progress tracking
with torch.no_grad():
    with tqdm(total=len(test_loader), desc="Generating Predictions", bar_format="{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}]", leave=True) as pbar:
        for batch in test_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            # Generate predictions
            outputs = model.generate(
                input_ids=input_ids,
                attention_mask=attention_mask,
                max_new_tokens=50,
                num_return_sequences=1
            )

            # Decode the generated output
            generated_texts = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
            predictions.extend(generated_texts)

            # Collect reference texts
            reference_texts = [tokenizer.decode(ids, skip_special_tokens=True) for ids in input_ids]
            references.extend(reference_texts)

            # Update the progress bar
            pbar.update(1)

# End the timer
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken for generating predictions: {elapsed_time:.2f} seconds")
# Out:
# Generating Predictions:   0%|          | 0/1384 [00:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   0%|          | 1/1384 [00:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   0%|          | 2/1384 [00:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   0%|          | 3/1384 [00:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   0%|          | 4/1384 [00:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   0%|          | 5/1384 [00:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   0%|          | 6/1384 [00:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 7/1384 [00:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 8/1384 [00:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 9/1384 [00:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 10/1384 [00:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 11/1384 [00:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 12/1384 [00:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 13/1384 [00:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 14/1384 [00:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 15/1384 [00:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 16/1384 [00:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|          | 17/1384 [00:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|▏         | 18/1384 [00:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|▏         | 19/1384 [00:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   1%|▏         | 20/1384 [00:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 21/1384 [00:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 22/1384 [00:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 23/1384 [00:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 24/1384 [00:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 25/1384 [00:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 26/1384 [00:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 27/1384 [00:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 28/1384 [00:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 29/1384 [00:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 30/1384 [00:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 31/1384 [00:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 32/1384 [00:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 33/1384 [00:23]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   2%|▏         | 34/1384 [00:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 35/1384 [00:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 36/1384 [00:25]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 37/1384 [00:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 38/1384 [00:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 39/1384 [00:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 40/1384 [00:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 41/1384 [00:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 42/1384 [00:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 43/1384 [00:30]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 44/1384 [00:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 45/1384 [00:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 46/1384 [00:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 47/1384 [00:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   3%|▎         | 48/1384 [00:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▎         | 49/1384 [00:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▎         | 50/1384 [00:35]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▎         | 51/1384 [00:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 52/1384 [00:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 53/1384 [00:37]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 54/1384 [00:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 55/1384 [00:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 56/1384 [00:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 57/1384 [00:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 58/1384 [00:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 59/1384 [00:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 60/1384 [00:42]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 61/1384 [00:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   4%|▍         | 62/1384 [00:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 63/1384 [00:44]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 64/1384 [00:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 65/1384 [00:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 66/1384 [00:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 67/1384 [00:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 68/1384 [00:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▍         | 69/1384 [00:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 70/1384 [00:49]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 71/1384 [00:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 72/1384 [00:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 73/1384 [00:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 74/1384 [00:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 75/1384 [00:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   5%|▌         | 76/1384 [00:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 77/1384 [00:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 78/1384 [00:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 79/1384 [00:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 80/1384 [00:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 81/1384 [00:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 82/1384 [00:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 83/1384 [00:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 84/1384 [00:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 85/1384 [00:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▌         | 86/1384 [01:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▋         | 87/1384 [01:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▋         | 88/1384 [01:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   6%|▋         | 89/1384 [01:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 90/1384 [01:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 91/1384 [01:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 92/1384 [01:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 93/1384 [01:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 94/1384 [01:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 95/1384 [01:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 96/1384 [01:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 97/1384 [01:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 98/1384 [01:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 99/1384 [01:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 100/1384 [01:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 101/1384 [01:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 102/1384 [01:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   7%|▋         | 103/1384 [01:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 104/1384 [01:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 105/1384 [01:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 106/1384 [01:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 107/1384 [01:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 108/1384 [01:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 109/1384 [01:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 110/1384 [01:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 111/1384 [01:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 112/1384 [01:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 113/1384 [01:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 114/1384 [01:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 115/1384 [01:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 116/1384 [01:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   8%|▊         | 117/1384 [01:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▊         | 118/1384 [01:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▊         | 119/1384 [01:23]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▊         | 120/1384 [01:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▊         | 121/1384 [01:25]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 122/1384 [01:25]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 123/1384 [01:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 124/1384 [01:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 125/1384 [01:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 126/1384 [01:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 127/1384 [01:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 128/1384 [01:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 129/1384 [01:30]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 130/1384 [01:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:   9%|▉         | 131/1384 [01:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 132/1384 [01:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 133/1384 [01:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 134/1384 [01:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 135/1384 [01:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 136/1384 [01:35]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 137/1384 [01:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|▉         | 138/1384 [01:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 139/1384 [01:37]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 140/1384 [01:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 141/1384 [01:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 142/1384 [01:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 143/1384 [01:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 144/1384 [01:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  10%|█         | 145/1384 [01:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 146/1384 [01:42]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 147/1384 [01:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 148/1384 [01:44]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 149/1384 [01:44]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 150/1384 [01:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 151/1384 [01:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 152/1384 [01:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 153/1384 [01:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 154/1384 [01:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█         | 155/1384 [01:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█▏        | 156/1384 [01:49]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█▏        | 157/1384 [01:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█▏        | 158/1384 [01:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  11%|█▏        | 159/1384 [01:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 160/1384 [01:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 161/1384 [01:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 162/1384 [01:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 163/1384 [01:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 164/1384 [01:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 165/1384 [01:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 166/1384 [01:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 167/1384 [01:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 168/1384 [01:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 169/1384 [01:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 170/1384 [01:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 171/1384 [02:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▏        | 172/1384 [02:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  12%|█▎        | 173/1384 [02:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 174/1384 [02:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 175/1384 [02:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 176/1384 [02:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 177/1384 [02:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 178/1384 [02:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 179/1384 [02:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 180/1384 [02:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 181/1384 [02:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 182/1384 [02:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 183/1384 [02:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 184/1384 [02:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 185/1384 [02:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  13%|█▎        | 186/1384 [02:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▎        | 187/1384 [02:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▎        | 188/1384 [02:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▎        | 189/1384 [02:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▎        | 190/1384 [02:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 191/1384 [02:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 192/1384 [02:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 193/1384 [02:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 194/1384 [02:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 195/1384 [02:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 196/1384 [02:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 197/1384 [02:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 198/1384 [02:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 199/1384 [02:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  14%|█▍        | 200/1384 [02:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 201/1384 [02:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 202/1384 [02:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 203/1384 [02:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 204/1384 [02:23]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 205/1384 [02:23]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 206/1384 [02:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▍        | 207/1384 [02:25]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 208/1384 [02:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 209/1384 [02:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 210/1384 [02:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 211/1384 [02:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 212/1384 [02:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 213/1384 [02:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  15%|█▌        | 214/1384 [02:30]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 215/1384 [02:30]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 216/1384 [02:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 217/1384 [02:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 218/1384 [02:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 219/1384 [02:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 220/1384 [02:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 221/1384 [02:35]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 222/1384 [02:35]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 223/1384 [02:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▌        | 224/1384 [02:37]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▋        | 225/1384 [02:37]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▋        | 226/1384 [02:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▋        | 227/1384 [02:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  16%|█▋        | 228/1384 [02:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 229/1384 [02:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 230/1384 [02:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 231/1384 [02:42]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 232/1384 [02:42]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 233/1384 [02:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 234/1384 [02:44]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 235/1384 [02:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 236/1384 [02:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 237/1384 [02:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 238/1384 [02:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 239/1384 [02:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 240/1384 [02:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 241/1384 [02:49]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  17%|█▋        | 242/1384 [02:49]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 243/1384 [02:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 244/1384 [02:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 245/1384 [02:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 246/1384 [02:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 247/1384 [02:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 248/1384 [02:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 249/1384 [02:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 250/1384 [02:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 251/1384 [02:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 252/1384 [02:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 253/1384 [02:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 254/1384 [02:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 255/1384 [02:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  18%|█▊        | 256/1384 [02:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▊        | 257/1384 [03:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▊        | 258/1384 [03:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▊        | 259/1384 [03:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 260/1384 [03:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 261/1384 [03:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 262/1384 [03:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 263/1384 [03:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 264/1384 [03:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 265/1384 [03:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 266/1384 [03:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 267/1384 [03:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 268/1384 [03:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  19%|█▉        | 269/1384 [03:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 270/1384 [03:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 271/1384 [03:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 272/1384 [03:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 273/1384 [03:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 274/1384 [03:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 275/1384 [03:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|█▉        | 276/1384 [03:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 277/1384 [03:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 278/1384 [03:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 279/1384 [03:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 280/1384 [03:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 281/1384 [03:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 282/1384 [03:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  20%|██        | 283/1384 [03:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 284/1384 [03:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 285/1384 [03:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 286/1384 [03:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 287/1384 [03:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 288/1384 [03:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 289/1384 [03:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 290/1384 [03:23]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 291/1384 [03:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 292/1384 [03:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 293/1384 [03:25]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██        | 294/1384 [03:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██▏       | 295/1384 [03:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██▏       | 296/1384 [03:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  21%|██▏       | 297/1384 [03:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 298/1384 [03:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 299/1384 [03:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 300/1384 [03:30]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 301/1384 [03:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 302/1384 [03:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 303/1384 [03:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 304/1384 [03:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 305/1384 [03:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 306/1384 [03:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 307/1384 [03:35]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 308/1384 [03:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 309/1384 [03:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 310/1384 [03:37]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  22%|██▏       | 311/1384 [03:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 312/1384 [03:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 313/1384 [03:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 314/1384 [03:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 315/1384 [03:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 316/1384 [03:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 317/1384 [03:42]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 318/1384 [03:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 319/1384 [03:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 320/1384 [03:44]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 321/1384 [03:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 322/1384 [03:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 323/1384 [03:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 324/1384 [03:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  23%|██▎       | 325/1384 [03:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▎       | 326/1384 [03:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▎       | 327/1384 [03:49]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▎       | 328/1384 [03:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 329/1384 [03:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 330/1384 [03:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 331/1384 [03:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 332/1384 [03:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 333/1384 [03:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 334/1384 [03:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 335/1384 [03:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 336/1384 [03:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 337/1384 [03:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 338/1384 [03:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  24%|██▍       | 339/1384 [03:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▍       | 340/1384 [03:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▍       | 341/1384 [03:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▍       | 342/1384 [04:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▍       | 343/1384 [04:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▍       | 344/1384 [04:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▍       | 345/1384 [04:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 346/1384 [04:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 347/1384 [04:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 348/1384 [04:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 349/1384 [04:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 350/1384 [04:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 351/1384 [04:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  25%|██▌       | 352/1384 [04:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 353/1384 [04:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 354/1384 [04:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 355/1384 [04:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 356/1384 [04:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 357/1384 [04:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 358/1384 [04:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 359/1384 [04:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 360/1384 [04:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 361/1384 [04:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 362/1384 [04:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▌       | 363/1384 [04:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▋       | 364/1384 [04:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▋       | 365/1384 [04:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  26%|██▋       | 366/1384 [04:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  27%|██▋       | 367/1384 [04:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  27%|██▋       | 368/1384 [04:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  27%|██▋       | 369/1384 [04:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  27%|██▋       | 370/1384 [04:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  27%|██▋       | 371/1384 [04:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
# Generating Predictions:  91%|█████████ | 1262/1384 [14:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  91%|█████████▏| 1263/1384 [14:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  91%|█████████▏| 1264/1384 [14:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  91%|█████████▏| 1265/1384 [14:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  91%|█████████▏| 1266/1384 [14:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1267/1384 [14:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1268/1384 [14:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1269/1384 [14:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1270/1384 [14:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1271/1384 [14:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1272/1384 [14:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1273/1384 [14:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1274/1384 [14:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1275/1384 [14:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1276/1384 [15:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1277/1384 [15:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1278/1384 [15:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1279/1384 [15:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  92%|█████████▏| 1280/1384 [15:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1281/1384 [15:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1282/1384 [15:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1283/1384 [15:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1284/1384 [15:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1285/1384 [15:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1286/1384 [15:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1287/1384 [15:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1288/1384 [15:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1289/1384 [15:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1290/1384 [15:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1291/1384 [15:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1292/1384 [15:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1293/1384 [15:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  93%|█████████▎| 1294/1384 [15:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▎| 1295/1384 [15:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▎| 1296/1384 [15:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▎| 1297/1384 [15:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1298/1384 [15:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1299/1384 [15:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1300/1384 [15:17]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1301/1384 [15:18]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1302/1384 [15:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1303/1384 [15:19]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1304/1384 [15:20]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1305/1384 [15:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1306/1384 [15:21]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  94%|█████████▍| 1307/1384 [15:22]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1308/1384 [15:23]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1309/1384 [15:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1310/1384 [15:24]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1311/1384 [15:25]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1312/1384 [15:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1313/1384 [15:26]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▍| 1314/1384 [15:27]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1315/1384 [15:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1316/1384 [15:28]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1317/1384 [15:29]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1318/1384 [15:30]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1319/1384 [15:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1320/1384 [15:31]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  95%|█████████▌| 1321/1384 [15:32]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1322/1384 [15:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1323/1384 [15:33]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1324/1384 [15:34]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1325/1384 [15:35]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1326/1384 [15:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1327/1384 [15:36]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1328/1384 [15:37]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1329/1384 [15:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1330/1384 [15:38]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1331/1384 [15:39]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▌| 1332/1384 [15:40]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▋| 1333/1384 [15:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▋| 1334/1384 [15:41]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  96%|█████████▋| 1335/1384 [15:42]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1336/1384 [15:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1337/1384 [15:43]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1338/1384 [15:44]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1339/1384 [15:45]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1340/1384 [15:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1341/1384 [15:46]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1342/1384 [15:47]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1343/1384 [15:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1344/1384 [15:48]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1345/1384 [15:49]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1346/1384 [15:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1347/1384 [15:50]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1348/1384 [15:51]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  97%|█████████▋| 1349/1384 [15:52]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1350/1384 [15:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1351/1384 [15:53]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1352/1384 [15:54]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1353/1384 [15:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1354/1384 [15:55]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1355/1384 [15:56]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1356/1384 [15:57]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1357/1384 [15:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1358/1384 [15:58]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1359/1384 [15:59]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1360/1384 [16:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1361/1384 [16:00]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1362/1384 [16:01]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  98%|█████████▊| 1363/1384 [16:02]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▊| 1364/1384 [16:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▊| 1365/1384 [16:03]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▊| 1366/1384 [16:04]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1367/1384 [16:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1368/1384 [16:05]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1369/1384 [16:06]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1370/1384 [16:07]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1371/1384 [16:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1372/1384 [16:08]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1373/1384 [16:09]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1374/1384 [16:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1375/1384 [16:10]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1376/1384 [16:11]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions:  99%|█████████▉| 1377/1384 [16:12]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|█████████▉| 1378/1384 [16:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|█████████▉| 1379/1384 [16:13]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|█████████▉| 1380/1384 [16:14]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|█████████▉| 1381/1384 [16:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|█████████▉| 1382/1384 [16:15]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|█████████▉| 1383/1384 [16:16]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating Predictions: 100%|██████████| 1384/1384 [16:17]
# Time taken for generating predictions: 977.32 seconds

# %%
from nltk.translate.bleu_score import corpus_bleu
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

# Prepare the references in the required format for BLEU calculation
formatted_references = [[word_tokenize(ref)] for ref in references]  # Tokenize reference texts
formatted_predictions = [word_tokenize(pred) for pred in predictions]  # Tokenize generated texts

# Calculate BLEU score
bleu_score = corpus_bleu(formatted_references, formatted_predictions)
print(f"BLEU Score: {bleu_score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# BLEU Score: 0.4063

# %%
pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.5)

# %%
from rouge_score import rouge_scorer

# Initialize the ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Calculate ROUGE scores
rouge_scores = {'rouge1': [], 'rouge2': [], 'rougeL': []}

for ref, pred in zip(references, predictions):
    scores = scorer.score(ref, pred)
    rouge_scores['rouge1'].append(scores['rouge1'].fmeasure)
    rouge_scores['rouge2'].append(scores['rouge2'].fmeasure)
    rouge_scores['rougeL'].append(scores['rougeL'].fmeasure)

# Calculate average ROUGE scores
average_rouge1 = sum(rouge_scores['rouge1']) / len(rouge_scores['rouge1'])
average_rouge2 = sum(rouge_scores['rouge2']) / len(rouge_scores['rouge2'])
average_rougeL = sum(rouge_scores['rougeL']) / len(rouge_scores['rougeL'])

# Print average ROUGE scores
print(f"Average ROUGE-1 Score: {average_rouge1:.4f}")
print(f"Average ROUGE-2 Score: {average_rouge2:.4f}")
print(f"Average ROUGE-L Score: {average_rougeL:.4f}")
# Out:
# Average ROUGE-1 Score: 0.4765
# Average ROUGE-2 Score: 0.4605
# Average ROUGE-L Score: 0.4765

# %%
import nltk
nltk.download('wordnet')
from nltk.translate import meteor_score
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Calculate METEOR scores
meteor_scores = []

# Tokenize references and predictions
for ref, pred in zip(references, predictions):
    # Tokenize both reference and prediction
    tokenized_ref = word_tokenize(ref)
    tokenized_pred = word_tokenize(pred)

    # Calculate the METEOR score using tokenized inputs (as lists)
    score = meteor_score.single_meteor_score(tokenized_ref, tokenized_pred)
    meteor_scores.append(score)

# Calculate average METEOR score
average_meteor = sum(meteor_scores) / len(meteor_scores)

# Print average METEOR score
print(f"Average METEOR Score: {average_meteor:.4f}")
# Out:
# Average METEOR Score: 0.6655

# %%
# Load the GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Set the pad token to the end-of-sequence token
tokenizer.pad_token = tokenizer.eos_token  # Assign pad token
tokenizer.pad_token_id = tokenizer.eos_token_id  # Ensure padding ID is the same as EOS

# Set the model to evaluation mode
model.eval()

print("Chatbot is ready! Type 'exit' to stop the conversation.")

while True:
    # Get user input
    input_text = input("You: ")

    # Check for exit condition
    if input_text.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye!")
        break

    # Tokenize the input
    encoded_input = tokenizer.encode_plus(
        input_text,
        return_tensors='pt',
        padding='max_length',
        truncation=True,
        max_length=50,
        clean_up_tokenization_spaces=True  # Set to avoid warnings
    )

    input_ids = encoded_input['input_ids'].to(device)
    attention_mask = encoded_input['attention_mask'].to(device)

    # Generate output
    with torch.no_grad():
        output = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=50,  # Generate up to 50 new tokens
            num_return_sequences=1
        )

    # Decode the generated output
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    print(f"Chatbot: {response}")
# Out:
# Chatbot is ready! Type 'exit' to stop the conversation.
# You: hi
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: hi. It's okay. I'm here. Where are you? We don't see you. I'm three quarters of the way up the lot behind the concession stand. Stay there. I don't want you within two hundred feet. Park down by
# You: what are you doing
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: what are you doingto meet the man who's gonna kill you? You know the rules. What about a drink on the way home? I'll meet him at his place at eleven o'clock. He'll come into the house. I don't think so.
# You: what drink
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: what drink? What? What? Oh! Who would jack us back? Hell! A umanu ujacku... You! I worked a gig with an actress! Four years!... You can't work in a gig with an actress! I...
# You: who is jack
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: who is jackandewizard? I cannot tell you. I cannot tell you. You've got to get somebody to talk to you. If we're not talking to each other you are. You must be crazy. She's my sister. She's the one
# You: who is your sister
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: who is your sister? My sister. There are many a beautiful women in this city. And you have no control over her. Believe me. She's got no idea what she's in. No? No. She knows things that nobody else knows. She is a
# You: who is jack again
# Keyword arguments {'clean_up_tokenization_spaces': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: who is jack again? The guy who called you the other day. He's been making phone calls for weeks. He had a girlfriend but she broke up with him last month. You know who it was? He's not a girlfriend. I'm sorry. Look I
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-f174fbde6f28> in <cell line: 13>()
#      13 while True:
#      14     # Get user input
# ---> 15     input_text = input("You: ")
#      16
#      17     # Check for exit condition
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
